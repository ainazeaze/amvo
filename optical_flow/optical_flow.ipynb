# %% [markdown]
# # TP4 - Flux optiques - visualisation et classification
#
# Dans ce TP nous travaillerons avec un sous-ensemble de vidéos du corpus `UCF Sports` que vous pouvez télécharger depuis la page Moodle du cours.
#
# Le fichier videos_samples.txt contient la liste des vidéos du corpus, ainsi que l'étiquette correspondante à chaque vidéo.
#
# Ci-dessous vous pouvez trouver quelques fonctions utiles pour la suite du TP.

# %%
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt

def bgr2grayscale_numpy(img):
    return .0722*img[:,:,0] + .7152*img[:,:,1] + .2126*img[:,:,2]
    
def read_file_list(input_file):
    frame_list, label_list = [], []
    with open(input_file) as f:
        for l in f:
            l = l.strip().split(' ')
            frame_list.append(l[0])
            label_list.append(l[1])
    return np.array(frame_list), np.array(label_list)

def read_video(video_file):
    capture = cv2.VideoCapture(video_file)
    frames = []
    ok, frame = capture.read()
    if not(ok):
        print("empty file"+video_file)
    while ok:
        frames.append(frame[...,::-1])
        ok, frame = capture.read()
    return np.array(frames)

def optical_flow_farneback(previous_frame, next_frame):
    return cv2.calcOpticalFlowFarneback(previous_frame, next_frame, None, 0.5, 3, 15, 3, 5, 1.2, 0)

# %% [markdown]
# ## Caractérisation d'une vidéo au moyen des descripteurs extraits depuis chaque image de celle-ci
#
# Nous pouvons traiter une vidéo comme une séquence d'images et, par conséquent, nous pouvons voir la description de la vidéo comme étant constituée des descripteurs extraits à partir des images la composant.
#
# Dans la suite, nous nous intéressons aux descripteurs globaux tels que les histogrammes.
#
# **Q1/** Ecrire un script python qui calcule les histogrammes couleur pour chaque image d'une vidéo.

# %%
def color_histogram(im, bins_per_channel=8):
    im = im.copy()

    bin_width = 256.0 / bins_per_channel
    im = (im / bin_width).astype(np.uint32)

    im = im[..., 0] * bins_per_channel**2 + im[..., 1] * bins_per_channel + im[..., 2]

    histogram = np.zeros((bins_per_channel**3,), dtype=np.float32)
    colors, counts = np.unique(im, return_counts=True)
    histogram[colors] = counts
    histogram = histogram / np.linalg.norm(histogram, ord=1)

    return histogram

# %%
import tensorflow as tf
def hist_video(video_path : str):
    hist = []
    images = read_video(video_path)
    for frame in images:
        tf.image.resize(frame, (128, 128))
        hist.append(color_histogram(frame))
    return np.array(hist)

# %% [markdown]
# **Q2/** Ecrire un script python qui calcule un histogramme moyen pour une vidéo, à partir des histogrammes couleur de chaque image la composant.

# %%
def hist_avg(video_path : str):
    hist = hist_video(video_path)
    return np.mean(hist, axis=0)

# %% [markdown]
# **Q3/** Si l'on considère l'histogramme moyen comme un descripteur pour une vidéo, mettez en place un protocole de classification sur les vidéos de la base `UCF Sports`. L'évaluation se fera en utilisant un processus de cross validation en 4 folds et un classifier de votre choix.
#
# Veuillez utiliser les configurations suivantes :
#
# a) utilisez que les données des classes `Diving-Side` / `Golf-Swing-Front`
#
# b) utilisez que les données des classes `Kicking-Front` / `Golf-Swing-Front`
#
# c) utilisez toutes les classes
#
# Reporter et discuter les résultats obtenus.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
import os

DATA_ROOT = "../ucf_sports_subset5/"
video_files, labels = read_file_list(DATA_ROOT + "videos.files")
video_paths = [os.path.join(DATA_ROOT, f) for f in video_files]

print("Computing average color histograms...")
descriptors = np.array([hist_avg(p) for p in video_paths])
print(f"Descriptors shape: {descriptors.shape}")

le = LabelEncoder()
labels_encoded = le.fit_transform(labels)

def classify_and_report(X, y, title):
    clf = SVC(kernel='rbf', C=10, gamma='scale')
    scores = cross_val_score(clf, X, y, cv=4, scoring='accuracy')
    print(f"\n{title}")
    print(f"  Accuracy per fold: {scores}")
    print(f"  Mean accuracy: {scores.mean():.4f} (+/- {scores.std():.4f})")
    return scores

mask_a = np.isin(labels, ['Diving-Side', 'Golf-Swing-Front'])
classify_and_report(descriptors[mask_a], labels_encoded[mask_a],
                    "a) Diving-Side vs Golf-Swing-Front")

mask_b = np.isin(labels, ['Kicking-Front', 'Golf-Swing-Front'])
classify_and_report(descriptors[mask_b], labels_encoded[mask_b],
                    "b) Kicking-Front vs Golf-Swing-Front")

classify_and_report(descriptors, labels_encoded, "c) All classes")
# Out:
# Computing average color histograms...
# Descriptors shape: (65, 512)
#
# a) Diving-Side vs Golf-Swing-Front
#   Accuracy per fold: [1. 1. 1. 1.]
#   Mean accuracy: 1.0000 (+/- 0.0000)
#
# b) Kicking-Front vs Golf-Swing-Front
#   Accuracy per fold: [1.         0.66666667 1.         0.5       ]
#   Mean accuracy: 0.7917 (+/- 0.2165)
#
# c) All classes
#   Accuracy per fold: [0.58823529 0.6875     0.625      0.5625    ]
#   Mean accuracy: 0.6158 (+/- 0.0470)
# array([0.58823529, 0.6875    , 0.625     , 0.5625    ])

# %% [markdown]
# **Q4/** Maintenant, nous allons considérer que chaque vidéo est constitués des quatres parties distinctes. Chaque partie contient un quart des images comme suit : `partie1=video[:n/4], partie2=video[n/4+1:n/2], partie3=video[2*n/4+1:3*n/4], partie4=video[3*n/4+1:]`. Désormais, nous souhaitons que le descripteur d'une vidéo soit composé de 4 histogrammes (un pour chaque partie de la vidéo). Ecrire un script python qui calcule ce nouveau descripteur.

# %%
def hist_avg_4p(video_path : str):
    desc = []
    images = read_video(video_path)
    n = len(images)
    
    parts = [
        images[:n//4],
        images[n//4+1:n//2],
        images[2*n//4+1:3*n//4],
        images[3*n//4+1:]
    ]
    
    for part in parts:
        part_hists = []
        for frame in part:
            resized = tf.image.resize(frame, (128, 128)).numpy().astype(np.uint8)
            part_hists.append(color_histogram(resized))
        desc.append(np.mean(part_hists, axis=0) if part_hists else np.zeros(512, dtype=np.float32))
    
    return np.concatenate(desc)

# %% [markdown]
# **Q5/** Reprendre le protocole de la **Q3** mettez en place un protocole de classification sur les vidéos de la base `UCF Sports`. L'évaluation se fera en utilisant un processus de cross validation en 4 folds et un classifier de votre choix.
#
# Veuillez reutiliser les mêmes configurations qu'en **Q3**. Reporter et discuter les résultats obtenus en insistant sur les avantages/désavantages rapportés par ce découpage de la vidéo.

# %%
print("Computing 4-part descriptors...")
descriptors_4p = np.array([hist_avg_4p(p) for p in video_paths])
print(f"Descriptors 4p shape: {descriptors_4p.shape}")

mask_a = np.isin(labels, ['Diving-Side', 'Golf-Swing-Front'])
classify_and_report(descriptors_4p[mask_a], labels_encoded[mask_a],
                    "a) Diving-Side vs Golf-Swing-Front (4 parts)")

mask_b = np.isin(labels, ['Kicking-Front', 'Golf-Swing-Front'])
classify_and_report(descriptors_4p[mask_b], labels_encoded[mask_b],
                    "b) Kicking-Front vs Golf-Swing-Front (4 parts)")

classify_and_report(descriptors_4p, labels_encoded, "c) All classes (4 parts)")
# Out:
# Computing 4-part descriptors...
# Descriptors 4p shape: (65, 2048)
#
# a) Diving-Side vs Golf-Swing-Front (4 parts)
#   Accuracy per fold: [1. 1. 1. 1.]
#   Mean accuracy: 1.0000 (+/- 0.0000)
#
# b) Kicking-Front vs Golf-Swing-Front (4 parts)
#   Accuracy per fold: [1.         0.66666667 1.         0.5       ]
#   Mean accuracy: 0.7917 (+/- 0.2165)
#
# c) All classes (4 parts)
#   Accuracy per fold: [0.58823529 0.6875     0.625      0.5625    ]
#   Mean accuracy: 0.6158 (+/- 0.0470)
# array([0.58823529, 0.6875    , 0.625     , 0.5625    ])

# %% [markdown]
# ## Visualiser les flux optiques (en tant qu'images RGB)
#
# Le flux optique permet de rendre compte du mouvement perçu dans la vidéo.
#
# Afin de s'affranchir de la spécificité de la texture/couleur des objets en mouvement, il est intéressant d'utiliser directement l'information de mouvement. Un objet rouge et un objet vert se déplaçant de la même manière, auront des histogrammes de couleurs différentes mais partagerons les mêmes propriétés de mouvement.
#
# En partant de cette observation, nous essayerons d'exploiter l'information du mouvement dans le cadre de la classification d'actions, en nous appuyant cette fois-ci sur l'information de mouvement.
#
# **Q6/** Ecrire un script python qui calcule les flux optiques entre chaque deux images successives pour une vidéo.
#
# Vous pouvez utiliser la fonction `calcOpticalFlowFarneback` avec les paramètres ci-dessous:
# ```
# cv2.calcOpticalFlowFarneback(previous_frame, next_frame, None, 0.5, 3, 15, 3, 5, 1.2, 0)
# ```
#
# N'oubliez pas que vous devez procéder à une conversion des images en niveaux de gris à priori. Vous pouvez utiliser la fonction `cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) ` pour cela.

# %%
def compute_optical_flows(video_path):
    frames = read_video(video_path)
    gray_frames = [cv2.cvtColor(f, cv2.COLOR_RGB2GRAY) for f in frames]
    flows = []
    for i in range(len(gray_frames) - 1):
        flow = optical_flow_farneback(gray_frames[i], gray_frames[i+1])
        flows.append(flow)
    return np.array(flows)

flows_test = compute_optical_flows(video_paths[0])

# %% [markdown]
# **Q7/** Pour visualiser les flux optiques, nous passons par une transformation des valeurs (dx,dy) associées à un pixel à une représentation HSV où :
#     * le canal `H` à la direction du flux `atan2(dy,dx)` et
#     * le canal `V` correspond à la magnitude du flux (`la norme 2 du vecteur (dx,dy)`) normée elle-même sur l'intervalle `[0..1]`
#
#
# ```
# flow_hsv[...,0] = np.arctan2(flow[...,1], flow[...,0])/np.pi*180. + 180.
# flow_hsv[...,1] = 1
# flow_hsv[...,2] = np.linalg.norm(flow, axis=2, ord=2)
# flow_hsv[...,2] = (flow_hsv[...,2] - np.min(flow_hsv[...,2])) / (np.max(flow_hsv[...,2]) - np.min(flow_hsv[...,2]))
# ```
#
# Selon que vous traitez l’ensemble des trames de flux d’une vidéo ou une trame de flux à la fois, vous devez créer le tensor `flow_hsv` de manière convenable au préalable :
#
# ```
# #une trame à la fois
# flow_hsv = np.empty((flow.shape[0],flow.shape[1],3), float32)
#
# #les trames d’une video à la fois
# flows_hsv = np.empty((flow.shape[0],flow.shape[1],flow.shape[2],3), float32)
# #dans ce cas, vous devez aussi remplacer axis=2, par axis=3 lors du calcul des normes
# ```
#
# L’intérêt de transformer l’ensemble des trames à la fois et d’obtenir une normalisation des flux qui tient compte de l’étendue complète des magnitudes observées sur l’intégralité de la vidéo. Sans cela, les faibles magnitudes présentes sur les trames comportant peu de mouvements seront perçues comme fortes lors de la visualisation.
#
# Nous procédons ensuite à une conversion de `HSV` vers `RGB` pour visualiser les flux ainsi obtenus. La conversion en `RGB` va générer des intensités comprises entre `[0..1]` sur chaque canal.
#
# Ecrivez une fonction qui permet de générer et sauvegarder les flux optiques sous formes d’images `RGB` pour une vidéo. Lors de la sauvegarde des images `RGB` pensez à multiplier par 255 (car valeurs comprises entre `[0..1]`) et de convertir en entiers (`int`) les valeurs contenues dans les tenseurs. Vous pouvez utiliser la fonction `np.astype` pour convertir tous les tenseurs en entiers.
#
# Pensez à utiliser le dossier `/local` pour réaliser les sauvegardes de vos données.

# %%
def flows_to_rgb(flows):
    flows_hsv = np.empty((flows.shape[0], flows.shape[1], flows.shape[2], 3), np.float32)
    flows_hsv[..., 0] = np.arctan2(flows[..., 1], flows[..., 0]) / np.pi * 180. + 180.
    flows_hsv[..., 1] = 1
    flows_hsv[..., 2] = np.linalg.norm(flows, axis=3, ord=2)
    flows_hsv[..., 2] = (flows_hsv[..., 2] - np.min(flows_hsv[..., 2])) / (np.max(flows_hsv[..., 2]) - np.min(flows_hsv[..., 2]) + 1e-8)
    
    rgb_frames = []
    for i in range(flows_hsv.shape[0]):
        hsv_img = flows_hsv[i].copy()
        hsv_img[..., 0] = hsv_img[..., 0] / 2
        hsv_img[..., 1] = (hsv_img[..., 1] * 255).astype(np.uint8)
        hsv_img[..., 2] = (hsv_img[..., 2] * 255).astype(np.uint8)
        hsv_img = hsv_img.astype(np.uint8)
        rgb = cv2.cvtColor(hsv_img, cv2.COLOR_HSV2RGB)
        rgb_frames.append(rgb)
    return np.array(rgb_frames)

def save_flow_rgb(video_path, output_dir="local/flow_rgb"):
    os.makedirs(output_dir, exist_ok=True)
    flows = compute_optical_flows(video_path)
    rgb_frames = flows_to_rgb(flows)
    basename = os.path.splitext(os.path.basename(video_path))[0]
    for i, frame in enumerate(rgb_frames):
        plt.imsave(os.path.join(output_dir, f"{basename}_flow_{i:04d}.png"), frame)
    return rgb_frames

rgb_test = save_flow_rgb(video_paths[0])
fig, axes = plt.subplots(1, 4, figsize=(16, 4))
for i, idx in enumerate(np.linspace(0, len(rgb_test)-1, 4, dtype=int)):
    axes[i].imshow(rgb_test[idx])
    axes[i].set_title(f"Frame {idx}")
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Vidéos - flux optiques comme orientations et magnitudes
#
# Nous pouvons aussi exploiter les flux optiques directement sans passer par une représentation `RGB` de ceux-ci.
#
# Nous considérons chaque point du flux comme un vecteur défini par son orientation et sa magnitude.
#
# L'espace de représentation des orientations est borné et s'étale entre `0°` et `359°`.
#
# En revanche, les magnitudes peuvent avoir des plages de représentation très larges, de part la vitesse de réalisation des actions, ou de part, les erreurs de mesure.
#
# Afin de pouvoir construire des histogrammes qui traitent de l'orientation et de la magnitude conjointement, nous pouvons nous appuyer sur les valeurs min et max des magnitudes observées au sein du corpus de données.
#
# **Q8/** Ecrivez une fonction qui transforme un flux optique `(dx,dy)` dans sa représentation ``orientation, magnitude)` en vous servant des règles suivantes:
# ```
# flow_mo[...,0] = (np.arctan2(flow[...,1], flow[...,0])/np.pi*180. + 180.).astype(int)
# flow_mo[...,1] = np.linalg.norm(flow, axis=2, ord=2).astype(int)
# ```
# Nous employons ici une conversion vers des `np.array` avec `dtype=int` afin de faciliter la construction d’histogrammes par la suite.

# %%
def flow_to_orientation_magnitude(flow):
    flow_mo = np.empty((flow.shape[0], flow.shape[1], 2), np.float32)
    flow_mo[..., 0] = (np.arctan2(flow[..., 1], flow[..., 0]) / np.pi * 180. + 180.).astype(int)
    flow_mo[..., 1] = np.linalg.norm(flow, axis=2, ord=2).astype(int)
    return flow_mo.astype(int)

def flows_to_orientation_magnitude(flows):
    return np.array([flow_to_orientation_magnitude(f) for f in flows])

flows_mo_test = flows_to_orientation_magnitude(flows_test)
print(f"Shape: {flows_mo_test.shape}")
print(f"Orientation range: [{flows_mo_test[...,0].min()}, {flows_mo_test[...,0].max()}]")
print(f"Magnitude range: [{flows_mo_test[...,1].min()}, {flows_mo_test[...,1].max()}]")
# Out:
# Shape: (54, 404, 720, 2)
# Orientation range: [0, 360]
# Magnitude range: [0, 115]

# %% [markdown]
# **Q9/** Ecrivez une fonction qui extrait l'ensemble de magnitudes observées sur la première vidéo de chaque classe de mouvement et sauvegardez-les dans un fichier.

# %%
unique_labels = np.unique(labels)
first_video_per_class = {}
for lbl in unique_labels:
    idx = np.where(labels == lbl)[0][0]
    first_video_per_class[lbl] = video_paths[idx]

all_magnitudes = []
for lbl, vpath in first_video_per_class.items():
    print(f"Processing {lbl}: {vpath}")
    flows = compute_optical_flows(vpath)
    flows_mo = flows_to_orientation_magnitude(flows)
    mags = flows_mo[..., 1].flatten()
    all_magnitudes.append(mags)

all_magnitudes = np.concatenate(all_magnitudes)
print(f"Total magnitude values: {len(all_magnitudes)}")
print(f"Min: {all_magnitudes.min()}, Max: {all_magnitudes.max()}, Mean: {all_magnitudes.mean():.2f}")

os.makedirs("local", exist_ok=True)
np.save("local/magnitudes_first_per_class.npy", all_magnitudes)
# Out:
# Processing Diving-Side: ../ucf_sports_subset5/videos/Diving-Side_001.avi
# Processing Golf-Swing-Back: ../ucf_sports_subset5/videos/Golf-Swing-Back_001.avi
# Processing Golf-Swing-Front: ../ucf_sports_subset5/videos/Golf-Swing-Front_001.avi
# Processing Golf-Swing-Side: ../ucf_sports_subset5/videos/Golf-Swing-Side_001.avi
# Processing Kicking-Front: ../ucf_sports_subset5/videos/Kicking-Front_001.avi
# Processing Kicking-Side: ../ucf_sports_subset5/videos/Kicking-Side_001.avi
# Processing Lifting: ../ucf_sports_subset5/videos/Lifting_001.avi
# Processing Riding-Horse: ../ucf_sports_subset5/videos/Riding-Horse_001.avi
# Processing Run-Side: ../ucf_sports_subset5/videos/Run-Side_001.avi
# Processing SkateBoarding-Front: ../ucf_sports_subset5/videos/SkateBoarding-Front_001.avi
# Processing Swing-Bench: ../ucf_sports_subset5/videos/Swing-Bench_001.avi
# Processing Swing-SideAngle: ../ucf_sports_subset5/videos/Swing-SideAngle_001.avi
# Processing Walk-Front: ../ucf_sports_subset5/videos/Walk-Front_001.avi
# Total magnitude values: 218378880
# Min: 0, Max: 115, Mean: 0.99

# %% [markdown]
# **Q10/**
# **a)** Ecrivez une fonction qui calcule un histogramme à 32 bins de ces magnitudes et visualisez-le afin d'identifier un seuil raisonnable pour les magnitudes apparaissant très rarement afin d'éliminer autant que possible les outliers. Les outliers corresponds souvent à des mesures abérantes causées par les erreurs se glissant lorsque les hypothèse de calcul de flux ne sont pas respectées. Ces magnitudes apparaîssent peu de fois par rapport aux magnitudes cohérentes.
#
# Vous pourriez itérer plusieurs fois en construisant des histogramme à 32 bins sur des plages de moins en moins étendue, car il se peut que lors de la première itération la plage de magnitudes soit très large pour analyser convenablement la distribution des magnitudes coherentes.
#
# **b)** Vous pourriez ensuite essayer de filtrer également les magnitudes trop petites, ne correspondant à des véritables mouvements. En construisant un  histogramme sur une plage proche de basses magnitudes (comprise en 0 et 4, par exemple), vous pourriez également essayer d'identifier à partir de quel moment il devient intéressant de considérer les flux optiques comme signifiant un véritable mouvement. Parfois, des nombreux points ne bougent pas dans l'image, mais à cause des erreurs de mesure (ouverture, discontinuités), on leur attribue des magnitudes supérieurs à zéro.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 4))

axes[0].hist(all_magnitudes, bins=32)
axes[0].set_title("a) Full range")
axes[0].set_xlabel("Magnitude")
axes[0].set_ylabel("Count")

mag_filtered_100 = all_magnitudes[all_magnitudes < 100]
axes[1].hist(mag_filtered_100, bins=32)
axes[1].set_title("a) Magnitudes < 100")
axes[1].set_xlabel("Magnitude")

mag_low = all_magnitudes[all_magnitudes < 5]
axes[2].hist(mag_low, bins=32)
axes[2].set_title("b) Magnitudes < 5 (low range)")
axes[2].set_xlabel("Magnitude")

plt.tight_layout()
plt.show()

MAG_MAX = 30
MAG_MIN = 1
print(f"Chosen thresholds: MAG_MIN={MAG_MIN}, MAG_MAX={MAG_MAX}")
print(f"Percentage kept: {np.mean((all_magnitudes >= MAG_MIN) & (all_magnitudes <= MAG_MAX))*100:.2f}%")
# Out:
# Chosen thresholds: MAG_MIN=1, MAG_MAX=30
# Percentage kept: 18.80%

# %% [markdown]
# **Q11/** Ecrivez une fonction qui filtre un flux optique en mettant à zéro les points dont la magnitude est inférieure au seuil minimal et supérieure au seuil maximal identifiés en **10**.

# %%
def filter_flow_mo(flow_mo, mag_min=MAG_MIN, mag_max=MAG_MAX):
    filtered = flow_mo.copy()
    mask = (filtered[..., 1] < mag_min) | (filtered[..., 1] > mag_max)
    filtered[mask] = 0
    return filtered

flow_mo_filtered_test = filter_flow_mo(flows_mo_test[0])
print(f"Before filtering - non-zero: {np.count_nonzero(flows_mo_test[0][...,1])}")
print(f"After filtering - non-zero: {np.count_nonzero(flow_mo_filtered_test[...,1])}")
# Out:
# Before filtering - non-zero: 115563
# After filtering - non-zero: 114387

# %% [markdown]
# **Q12/** Ecrivez une fonction qui calcule un histogramme de flux optique en partant de la représentation `(orientation, magnitude)` en ignorant les points ayant une `magnitude==0`.
#
# Pour cela vous devrez fragmenter l’espace `(orientation, magnitude)`. Si vous souhaitez disposer de `o_bins` pour fragmenter l’orientation et de `m_bins` pour fragmenter la magnitude, vous allez construire un vecteur disposant de `o_bins*m_bins` cases.
#
# L’étendue d’une cellule sera de `o_bin_etendue = 360/o_bins` degrés pour les orientations et de `m_bin_etendue = max_mag/m_bins` pour les magnitudes.
# Vous pourrez ensuite adapter la fonction color_histogram (fournie en *TP2*) pour remplir l’histogramme.
#
# Vous pouvez aussi choisir une implémentation moins efficace en parcourant les points composants le flux optiques et en incrémentant la case correspondante `bin_o*m_bins+bin_m`, où :
# * `bin_o` correspond au bin d’orientation où le point `(o,m)` devra se trouver (`=o/o_bin_etendue`) et
# * `bin_m` correspond au bin de magnitude où le point `(o,m)` devra se trouver (`=m/m_bin_etendue`).

# %%
def optical_flow_histogram(flow_mo, o_bins=12, m_bins=8, max_mag=MAG_MAX):
    o_bin_extent = 360.0 / o_bins
    m_bin_extent = max_mag / m_bins
    histogram = np.zeros(o_bins * m_bins, dtype=np.float32)
    
    mask = flow_mo[..., 1] > 0
    orientations = flow_mo[mask][:, 0]
    magnitudes = flow_mo[mask][:, 1]
    
    bin_o = np.clip((orientations / o_bin_extent).astype(int), 0, o_bins - 1)
    bin_m = np.clip((magnitudes / m_bin_extent).astype(int), 0, m_bins - 1)
    indices = bin_o * m_bins + bin_m
    
    for idx in indices:
        histogram[idx] += 1
    
    norm = np.linalg.norm(histogram, ord=1)
    if norm > 0:
        histogram /= norm
    return histogram

hist_test = optical_flow_histogram(flow_mo_filtered_test)
print(f"Flow histogram shape: {hist_test.shape}")
print(f"Sum: {hist_test.sum():.4f}")
# Out:
# Flow histogram shape: (96,)
# Sum: 1.0000

# %% [markdown]
# **Q13/** Calculez un histogramme moyen pour une vidéo en partant des histogramme de flux optique calculés entre deux images successives et filtré comme indiqué en **Q11**.

# %%
def avg_flow_histogram(video_path, o_bins=12, m_bins=8, mag_min=MAG_MIN, mag_max=MAG_MAX):
    flows = compute_optical_flows(video_path)
    flows_mo = flows_to_orientation_magnitude(flows)
    hists = []
    for flow_mo in flows_mo:
        filtered = filter_flow_mo(flow_mo, mag_min, mag_max)
        h = optical_flow_histogram(filtered, o_bins, m_bins, mag_max)
        hists.append(h)
    return np.mean(hists, axis=0)

hist_avg_flow_test = avg_flow_histogram(video_paths[0])
print(f"Average flow histogram: {hist_avg_flow_test}")
# Out:
# Average flow histogram: [0.00826491 0.00846993 0.00684562 0.00312283 0.00347934 0.00216792
#  0.00127344 0.00088875 0.00808922 0.00811827 0.00752863 0.00438715
#  0.00420034 0.00315043 0.00121173 0.0006004  0.01329763 0.01151566
#  0.00978169 0.00597595 0.00600709 0.00422233 0.00232745 0.00126003
#  0.03119741 0.02484944 0.04443853 0.03396812 0.05428517 0.04050871
#  0.01752313 0.00969215 0.13374238 0.06504211 0.02949042 0.00684021
#  0.00324447 0.00230561 0.00135364 0.00066519 0.04326601 0.03223429
#  0.00949852 0.00375512 0.00395577 0.00220538 0.00092461 0.00047619
#  0.02258512 0.01782086 0.01168098 0.00363036 0.00285353 0.00237233
#  0.00111976 0.00128347 0.00887482 0.01100023 0.01304115 0.00726444
#  0.00459604 0.00189414 0.00100123 0.00034832 0.00840719 0.0116272
#  0.01000718 0.0072311  0.0076324  0.00457053 0.0034208  0.00285704
#  0.00740287 0.00913266 0.00840448 0.00470411 0.00576648 0.0046035
#  0.0038931  0.00419546 0.00624205 0.00701583 0.0057346  0.00289599
#  0.00283168 0.00231947 0.00151922 0.0017686  0.00767073 0.00766437
#  0.00671636 0.00370978 0.00291458 0.00235387 0.0012035  0.0005672 ]

# %% [markdown]
# **Q14/** Réappliquer les protocoles de classification de la **Q3 et Q5** sur ces nouveaux histogrammes moyens. Reporter et discuter les résultats.

# %%
print("Computing average flow histograms for all videos...")
flow_descriptors = np.array([avg_flow_histogram(p) for p in video_paths])
print(f"Flow descriptors shape: {flow_descriptors.shape}")

mask_a = np.isin(labels, ['Diving-Side', 'Golf-Swing-Front'])
classify_and_report(flow_descriptors[mask_a], labels_encoded[mask_a],
                    "a) Diving-Side vs Golf-Swing-Front (flow hist)")

mask_b = np.isin(labels, ['Kicking-Front', 'Golf-Swing-Front'])
classify_and_report(flow_descriptors[mask_b], labels_encoded[mask_b],
                    "b) Kicking-Front vs Golf-Swing-Front (flow hist)")

classify_and_report(flow_descriptors, labels_encoded, "c) All classes (flow hist)")

# 4 part
def avg_flow_histogram_4p(video_path, o_bins=12, m_bins=8, mag_min=MAG_MIN, mag_max=MAG_MAX):
    flows = compute_optical_flows(video_path)
    flows_mo = flows_to_orientation_magnitude(flows)
    n = len(flows_mo)
    parts = [flows_mo[:n//4], flows_mo[n//4+1:n//2], flows_mo[2*n//4+1:3*n//4], flows_mo[3*n//4+1:]]
    desc = []
    for part in parts:
        if len(part) == 0:
            desc.append(np.zeros(o_bins * m_bins, dtype=np.float32))
            continue
        hists = []
        for flow_mo in part:
            filtered = filter_flow_mo(flow_mo, mag_min, mag_max)
            hists.append(optical_flow_histogram(filtered, o_bins, m_bins, mag_max))
        desc.append(np.mean(hists, axis=0))
    return np.concatenate(desc)

print("\nComputing 4-part flow histograms...")
flow_descriptors_4p = np.array([avg_flow_histogram_4p(p) for p in video_paths])
print(f"Flow descriptors 4p shape: {flow_descriptors_4p.shape}")

mask_a = np.isin(labels, ['Diving-Side', 'Golf-Swing-Front'])
classify_and_report(flow_descriptors_4p[mask_a], labels_encoded[mask_a],
                    "a) Diving-Side vs Golf-Swing-Front (flow hist 4p)")

mask_b = np.isin(labels, ['Kicking-Front', 'Golf-Swing-Front'])
classify_and_report(flow_descriptors_4p[mask_b], labels_encoded[mask_b],
                    "b) Kicking-Front vs Golf-Swing-Front (flow hist 4p)")

classify_and_report(flow_descriptors_4p, labels_encoded, "c) All classes (flow hist 4p)")
# Out:
# Computing average flow histograms for all videos...
# Flow descriptors shape: (65, 96)
#
# a) Diving-Side vs Golf-Swing-Front (flow hist)
#   Accuracy per fold: [1. 1. 1. 1.]
#   Mean accuracy: 1.0000 (+/- 0.0000)
#
# b) Kicking-Front vs Golf-Swing-Front (flow hist)
#   Accuracy per fold: [0.33333333 0.33333333 0.5        0.5       ]
#   Mean accuracy: 0.4167 (+/- 0.0833)
#
# c) All classes (flow hist)
#   Accuracy per fold: [0.47058824 0.625      0.4375     0.5625    ]
#   Mean accuracy: 0.5239 (+/- 0.0742)
#
# Computing 4-part flow histograms...
# Flow descriptors 4p shape: (65, 384)
#
# a) Diving-Side vs Golf-Swing-Front (flow hist 4p)
#   Accuracy per fold: [0.66666667 0.66666667 1.         1.        ]
#   Mean accuracy: 0.8333 (+/- 0.1667)
#
# b) Kicking-Front vs Golf-Swing-Front (flow hist 4p)
#   Accuracy per fold: [0.33333333 0.33333333 0.         0.5       ]
#   Mean accuracy: 0.2917 (+/- 0.1816)
#
# c) All classes (flow hist 4p)
#   Accuracy per fold: [0.52941176 0.5        0.5625     0.5625    ]
#   Mean accuracy: 0.5386 (+/- 0.0261)
# array([0.52941176, 0.5       , 0.5625    , 0.5625    ])

# %% [markdown]
# **Q15/** Réappliquer le protocole de classification de la **Q3 et Q5** en considérant cette fois-ci uniquement des histogrammes d'orientation (en ignorant les magnitudes des flux) et en laissant également de côté les flux ayant une `magnitude == 0`. Reporter et discuter les résultats.

# %%
def orientation_histogram(flow_mo, o_bins=36):
    o_bin_extent = 360.0 / o_bins
    histogram = np.zeros(o_bins, dtype=np.float32)
    
    mask = flow_mo[..., 1] > 0
    orientations = flow_mo[mask][:, 0]
    
    bin_o = np.clip((orientations / o_bin_extent).astype(int), 0, o_bins - 1)
    for idx in bin_o:
        histogram[idx] += 1
    
    norm = np.linalg.norm(histogram, ord=1)
    if norm > 0:
        histogram /= norm
    return histogram

def avg_orientation_histogram(video_path, o_bins=36, mag_min=MAG_MIN, mag_max=MAG_MAX):
    flows = compute_optical_flows(video_path)
    flows_mo = flows_to_orientation_magnitude(flows)
    hists = []
    for flow_mo in flows_mo:
        filtered = filter_flow_mo(flow_mo, mag_min, mag_max)
        hists.append(orientation_histogram(filtered, o_bins))
    return np.mean(hists, axis=0)

def avg_orientation_histogram_4p(video_path, o_bins=36, mag_min=MAG_MIN, mag_max=MAG_MAX):
    flows = compute_optical_flows(video_path)
    flows_mo = flows_to_orientation_magnitude(flows)
    n = len(flows_mo)
    parts = [flows_mo[:n//4], flows_mo[n//4+1:n//2], flows_mo[2*n//4+1:3*n//4], flows_mo[3*n//4+1:]]
    desc = []
    for part in parts:
        if len(part) == 0:
            desc.append(np.zeros(o_bins, dtype=np.float32))
            continue
        hists = []
        for flow_mo in part:
            filtered = filter_flow_mo(flow_mo, mag_min, mag_max)
            hists.append(orientation_histogram(filtered, o_bins))
        desc.append(np.mean(hists, axis=0))
    return np.concatenate(desc)

print("Computing orientation-only histograms...")
orient_descriptors = np.array([avg_orientation_histogram(p) for p in video_paths])
orient_descriptors_4p = np.array([avg_orientation_histogram_4p(p) for p in video_paths])

mask_a = np.isin(labels, ['Diving-Side', 'Golf-Swing-Front'])
classify_and_report(orient_descriptors[mask_a], labels_encoded[mask_a],
                    "a) Diving-Side vs Golf-Swing-Front (orient)")
mask_b = np.isin(labels, ['Kicking-Front', 'Golf-Swing-Front'])
classify_and_report(orient_descriptors[mask_b], labels_encoded[mask_b],
                    "b) Kicking-Front vs Golf-Swing-Front (orient)")
classify_and_report(orient_descriptors, labels_encoded, "c) All classes (orient)")

print("\n--- 4 parts ---")
mask_a = np.isin(labels, ['Diving-Side', 'Golf-Swing-Front'])
classify_and_report(orient_descriptors_4p[mask_a], labels_encoded[mask_a],
                    "a) Diving-Side vs Golf-Swing-Front (orient 4p)")
mask_b = np.isin(labels, ['Kicking-Front', 'Golf-Swing-Front'])
classify_and_report(orient_descriptors_4p[mask_b], labels_encoded[mask_b],
                    "b) Kicking-Front vs Golf-Swing-Front (orient 4p)")
classify_and_report(orient_descriptors_4p, labels_encoded, "c) All classes (orient 4p)")
# Out:
# Computing orientation-only histograms...
#
# a) Diving-Side vs Golf-Swing-Front (orient)
#   Accuracy per fold: [0.66666667 1.         1.         1.        ]
#   Mean accuracy: 0.9167 (+/- 0.1443)
#
# b) Kicking-Front vs Golf-Swing-Front (orient)
#   Accuracy per fold: [0.33333333 0.33333333 0.         0.5       ]
#   Mean accuracy: 0.2917 (+/- 0.1816)
#
# c) All classes (orient)
#   Accuracy per fold: [0.41176471 0.4375     0.5        0.4375    ]
#   Mean accuracy: 0.4467 (+/- 0.0325)
#
# --- 4 parts ---
#
# a) Diving-Side vs Golf-Swing-Front (orient 4p)
#   Accuracy per fold: [0.33333333 0.33333333 1.         0.5       ]
#   Mean accuracy: 0.5417 (+/- 0.2732)
#
# b) Kicking-Front vs Golf-Swing-Front (orient 4p)
#   Accuracy per fold: [0.         0.33333333 0.         0.5       ]
#   Mean accuracy: 0.2083 (+/- 0.2165)
#
# c) All classes (orient 4p)
#   Accuracy per fold: [0.41176471 0.375      0.5625     0.5       ]
#   Mean accuracy: 0.4623 (+/- 0.0735)
# array([0.41176471, 0.375     , 0.5625    , 0.5       ])

# %% [markdown]
# **Q16/** Faites varier les seuils de filtrage obtenus en **Q10** et refaites les experimentations de la **Q14** (au minium 2 autres valeurs pour le seuil haut et 2 autres valeurs pour le seuil bas). Reporter et discuter les résultats.

# %%
threshold_configs = [
    (1, 30),
    (0, 30),
    (2, 30),
    (1, 15),
    (1, 50),
    (2, 15),
    (0, 50),
]

print("Q16 - Varying thresholds for flow histogram classification (Q14 protocol)\n")
for mag_min, mag_max in threshold_configs:
    print(f"=== MAG_MIN={mag_min}, MAG_MAX={mag_max} ===")
    descs = np.array([avg_flow_histogram(p, mag_min=mag_min, mag_max=mag_max) for p in video_paths])
    
    mask_a = np.isin(labels, ['Diving-Side', 'Golf-Swing-Front'])
    classify_and_report(descs[mask_a], labels_encoded[mask_a],
                        f"a) Diving-Side vs Golf-Swing-Front (min={mag_min}, max={mag_max})")
    
    mask_b = np.isin(labels, ['Kicking-Front', 'Golf-Swing-Front'])
    classify_and_report(descs[mask_b], labels_encoded[mask_b],
                        f"b) Kicking-Front vs Golf-Swing-Front (min={mag_min}, max={mag_max})")
    
    classify_and_report(descs, labels_encoded,
                        f"c) All classes (min={mag_min}, max={mag_max})")
    print()
# Out:
# Q16 - Varying thresholds for flow histogram classification (Q14 protocol)
#
# === MAG_MIN=1, MAG_MAX=30 ===
#
# a) Diving-Side vs Golf-Swing-Front (min=1, max=30)
#   Accuracy per fold: [1. 1. 1. 1.]
#   Mean accuracy: 1.0000 (+/- 0.0000)
#
# b) Kicking-Front vs Golf-Swing-Front (min=1, max=30)
#   Accuracy per fold: [0.33333333 0.33333333 0.5        0.5       ]
#   Mean accuracy: 0.4167 (+/- 0.0833)
#
# c) All classes (min=1, max=30)
#   Accuracy per fold: [0.47058824 0.625      0.4375     0.5625    ]
#   Mean accuracy: 0.5239 (+/- 0.0742)
#
# === MAG_MIN=0, MAG_MAX=30 ===
#
# a) Diving-Side vs Golf-Swing-Front (min=0, max=30)
#   Accuracy per fold: [1. 1. 1. 1.]
#   Mean accuracy: 1.0000 (+/- 0.0000)
#
# b) Kicking-Front vs Golf-Swing-Front (min=0, max=30)
#   Accuracy per fold: [0.33333333 0.33333333 0.5        0.5       ]
#   Mean accuracy: 0.4167 (+/- 0.0833)
#
# c) All classes (min=0, max=30)
#   Accuracy per fold: [0.47058824 0.625      0.4375     0.5625    ]
#   Mean accuracy: 0.5239 (+/- 0.0742)
#
# === MAG_MIN=2, MAG_MAX=30 ===
#
# a) Diving-Side vs Golf-Swing-Front (min=2, max=30)
#   Accuracy per fold: [1.         0.33333333 1.         1.        ]
#   Mean accuracy: 0.8333 (+/- 0.2887)
#
# b) Kicking-Front vs Golf-Swing-Front (min=2, max=30)
#   Accuracy per fold: [0.66666667 0.33333333 0.         0.5       ]
#   Mean accuracy: 0.3750 (+/- 0.2465)
#
# c) All classes (min=2, max=30)
#   Accuracy per fold: [0.58823529 0.5625     0.625      0.5       ]
#   Mean accuracy: 0.5689 (+/- 0.0456)
#
# === MAG_MIN=1, MAG_MAX=15 ===
#
# a) Diving-Side vs Golf-Swing-Front (min=1, max=15)
#   Accuracy per fold: [1. 1. 1. 1.]
#   Mean accuracy: 1.0000 (+/- 0.0000)
#
# b) Kicking-Front vs Golf-Swing-Front (min=1, max=15)
#   Accuracy per fold: [0.66666667 0.66666667 0.5        1.        ]
#   Mean accuracy: 0.7083 (+/- 0.1816)
#
# c) All classes (min=1, max=15)
#   Accuracy per fold: [0.47058824 0.5        0.5        0.5625    ]
#   Mean accuracy: 0.5083 (+/- 0.0335)
#
# === MAG_MIN=1, MAG_MAX=50 ===
#
# a) Diving-Side vs Golf-Swing-Front (min=1, max=50)
#   Accuracy per fold: [0.66666667 1.         1.         1.        ]
#   Mean accuracy: 0.9167 (+/- 0.1443)
#
# b) Kicking-Front vs Golf-Swing-Front (min=1, max=50)
#   Accuracy per fold: [0.33333333 0.33333333 0.         0.5       ]
#   Mean accuracy: 0.2917 (+/- 0.1816)
#
# c) All classes (min=1, max=50)
#   Accuracy per fold: [0.47058824 0.625      0.5        0.5625    ]
#   Mean accuracy: 0.5395 (+/- 0.0595)
#
# === MAG_MIN=2, MAG_MAX=15 ===
#
# a) Diving-Side vs Golf-Swing-Front (min=2, max=15)
#   Accuracy per fold: [1.         0.33333333 1.         1.        ]
#   Mean accuracy: 0.8333 (+/- 0.2887)
#
# b) Kicking-Front vs Golf-Swing-Front (min=2, max=15)
#   Accuracy per fold: [0.66666667 0.33333333 0.         0.5       ]
#   Mean accuracy: 0.3750 (+/- 0.2465)
#
# c) All classes (min=2, max=15)
#   Accuracy per fold: [0.52941176 0.5        0.5625     0.4375    ]
#   Mean accuracy: 0.5074 (+/- 0.0460)
#
# === MAG_MIN=0, MAG_MAX=50 ===
#
# a) Diving-Side vs Golf-Swing-Front (min=0, max=50)
#   Accuracy per fold: [0.66666667 1.         1.         1.        ]
#   Mean accuracy: 0.9167 (+/- 0.1443)
#
# b) Kicking-Front vs Golf-Swing-Front (min=0, max=50)
#   Accuracy per fold: [0.33333333 0.33333333 0.         0.5       ]
#   Mean accuracy: 0.2917 (+/- 0.1816)
#
# c) All classes (min=0, max=50)
#   Accuracy per fold: [0.47058824 0.625      0.5        0.5625    ]
#   Mean accuracy: 0.5395 (+/- 0.0595)

# %% [markdown]
# ## Vidéos - flux optiques comme images RGB (optionnel)
#
# **Q17/** A partir des images `RGB` illustrant les flux (voir **Q7**), vous pouvez réappliquer la même méthodologie décrite en **Q1**-**Q2** afin de calculer un descripteur global de la vidéo.

# %% [markdown]
# **Q18/** Ecrire une fonction qui calcule un histogramme moyen pour une vidéo, à partir des histogrammes couleur de chaque image `RGB` illustrant le flux optique entre deux images successives.

# %% [markdown]
# **Q19/** Si l'on considère l'histogramme moyen des images RGB des flux comme un descripteur pour une vidéo, mettez en place les protocoles de classification décrites dans les **Q3 et Q5**.
#
# Reporter et discuter les résultats.
